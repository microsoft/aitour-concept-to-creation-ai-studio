# %% [markdown]
# # Evaluating generation quality performance metrics of the flow

# %%
# Configuring Azure OpenAI service connection

import os
from dotenv import load_dotenv
load_dotenv()

# Initialize Azure OpenAI Connection
model_config = {
        "azure_deployment": "gpt-4",
        "api_version": os.environ["AZURE_OPENAI_API_VERSION"],
        "azure_endpoint": os.environ["AZURE_OPENAI_ENDPOINT"],
        "api_key": os.environ["AZURE_OPENAI_KEY"]
}

# %%
# Uploading test dataset
import pandas as pd

test_data_path = "../data/test_dataset.jsonl"

df = pd.read_json(test_data_path, lines=True)
df.head()
# Out:
#                                             question
# 0  Create the website copy for the tents catalog ...
# 1  Create the textual assets for the sleeping bag...
# 2  Draft the website copy for the hiking shoes we...

# %%
# Importing class evaluators 
from create_website_copy_request import get_response
from azure.ai.evaluation import RelevanceEvaluator, GroundednessEvaluator, FluencyEvaluator, CoherenceEvaluator, evaluate

relevance_evaluator = RelevanceEvaluator(model_config)
groundedness_evaluator = GroundednessEvaluator(model_config)
fluency_evaluator = FluencyEvaluator(model_config)
coherence_evaluator = CoherenceEvaluator(model_config)
# Out:
# [INFO] Could not import AIAgentConverter. Please install the dependency with `pip install azure-ai-projects`.

# %%
# Create unique id for each run with date and time
from datetime import datetime
run_id = datetime.now().strftime("%Y%m%d%H%M%S")
run_id = f"{run_id}_chat_evaluation_sdk"    
print(run_id)
# Out:
# 20250506151528_chat_evaluation_sdk

# %%
subscription_id = os.environ["AZURE_SUBSCRIPTION_ID"]
resource_group_name= os.environ["AZURE_RESOURCE_GROUP"]
project_name = os.environ["AZURE_AI_PROJECT_NAME"]

azure_ai_project = {
    "subscription_id": subscription_id,
    "resource_group_name": resource_group_name,
    "project_name": project_name
}

# %%
import json

def create_response_data(df):
    results = []

    for index, row in df.iterrows():
        question = row['question']
        
        # Run get response
        response = get_response(question)
                
        # Add results to list
        result = {
            'query': question,
            'context': response["context"],
            'response': response["answer"]
        }
        results.append(result)

    # Save results to a JSONL file
    with open('run_results.jsonl', 'w') as file:
        for result in results:
            file.write(json.dumps(result) + '\n')
    return results

# %%
# Step 1: Run web_designer_app against test dataset
# Step 2: Evaluate outputs (answer and context) against generation quality metrics
# %pip install azure-ai-evaluation[remote]
response_results = create_response_data(df)
result_eval = evaluate(
    evaluation_name=run_id,
    data="run_results.jsonl",
    evaluators={
        "relevance": relevance_evaluator,
        "fluency": fluency_evaluator,
        "coherence": coherence_evaluator,
        "groundedness": groundedness_evaluator,
    },
    # column mapping    
    evaluator_config={
        "default": {
            "query": "${data.query}",
            "response": "${data.response}",
            "context": "${data.context}",
        },
    },
    azure_ai_project = azure_ai_project, # comment this line if you don't want to push results to your Azure AI Project
    output_path="./eval_results.jsonl"
)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-ai-evaluation[remote] in /usr/local/lib/python3.11/site-packages (1.6.0)
# WARNING: azure-ai-evaluation 1.6.0 does not provide the extra 'remote'
# Requirement already satisfied: promptflow-devkit>=1.17.1 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.18.0)
# Requirement already satisfied: promptflow-core>=1.17.1 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.18.0)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (2.10.1)
# Requirement already satisfied: azure-identity>=1.16.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.21.0)
# Requirement already satisfied: azure-core>=1.30.2 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.34.0)
# Requirement already satisfied: nltk>=3.9.1 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (3.9.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (12.25.1)
# Requirement already satisfied: httpx>=0.25.1 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (0.28.1)
# Requirement already satisfied: pandas<3.0.0,>=2.1.2 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (2.2.3)
# Requirement already satisfied: openai>=1.73.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.77.0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (0.18.10)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (0.7.1)
# Requirement already satisfied: Jinja2>=3.1.6 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (3.1.6)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation[remote]) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation[remote]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation[remote]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation[remote]) (2025.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.11/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->azure-ai-evaluation[remote]) (0.2.12)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.11/site-packages (from azure-core>=1.30.2->azure-ai-evaluation[remote]) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/site-packages (from azure-core>=1.30.2->azure-ai-evaluation[remote]) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/site-packages (from azure-core>=1.30.2->azure-ai-evaluation[remote]) (4.13.2)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.11/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation[remote]) (44.0.3)
# Requirement already satisfied: msal>=1.30.0 in /usr/local/lib/python3.11/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation[remote]) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.11/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation[remote]) (1.3.1)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.11/site-packages (from azure-storage-blob>=12.10.0->azure-ai-evaluation[remote]) (0.7.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation[remote]) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation[remote]) (2.22)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation[remote]) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation[remote]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation[remote]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation[remote]) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.1->azure-ai-evaluation[remote]) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from Jinja2>=3.1.6->azure-ai-evaluation[remote]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation[remote]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation[remote]) (2.4.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.11/site-packages (from msrest>=0.6.21->azure-ai-evaluation[remote]) (2.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/site-packages (from openai>=1.73.0->azure-ai-evaluation[remote]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/site-packages (from openai>=1.73.0->azure-ai-evaluation[remote]) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/site-packages (from openai>=1.73.0->azure-ai-evaluation[remote]) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/site-packages (from openai>=1.73.0->azure-ai-evaluation[remote]) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.73.0->azure-ai-evaluation[remote]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.73.0->azure-ai-evaluation[remote]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.73.0->azure-ai-evaluation[remote]) (0.4.0)
# Requirement already satisfied: docstring_parser in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (0.115.12)
# Requirement already satisfied: filetype>=1.2.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (3.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (4.23.0)
# Requirement already satisfied: promptflow-tracing==1.18.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (1.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (6.1.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /usr/local/lib/python3.11/site-packages (from promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (1.32.1)
# Requirement already satisfied: tiktoken>=0.4.0 in /usr/local/lib/python3.11/site-packages (from promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (0.9.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (0.46.2)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (1.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (0.24.0)
# Requirement already satisfied: opentelemetry-api==1.32.1 in /usr/local/lib/python3.11/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (1.32.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /usr/local/lib/python3.11/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (0.53b1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/site-packages (from opentelemetry-api==1.32.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/site-packages (from opentelemetry-api==1.32.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api==1.32.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (3.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api==1.32.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation[remote]) (1.17.2)
# Requirement already satisfied: argcomplete>=3.2.3 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.6.2)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.0.0b36)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (0.4.6)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.18.0)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (5.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.1.41)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.26.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.32.1)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (11.0.0)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.0.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (2.0.40)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.0.2)
# Requirement already satisfied: fixedint==0.1.6 in /usr/local/lib/python3.11/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (0.1.6)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.11/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (10.0.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (6.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (5.0.2)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.4.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (25.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.1 in /usr/local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.32.1)
# Requirement already satisfied: opentelemetry-proto==1.32.1 in /usr/local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (1.32.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.11/site-packages (from opentelemetry-proto==1.32.1->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (5.29.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (3.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-evaluation[remote]) (3.2.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation[remote]) (10.7.0)
# Note: you may need to restart the kernel to use updated packages.
# question: Create the website copy for the tents catalog page
# embedding done
# index name: products-catalog
# context: [{'id': 'cHJvZHVjdF9pbmZvXzE1Lm1kMA==', 'title': 'Information about product item_number: 15', 'content': "# Information about product item_number: 15\n\n# Information about product item_number: 15\nSkyView 2-Person Tent, price $200,\n\n## Brand\nOutdoorLiving\n\n## Category\nTents\n\n## Features\n- Spacious interior comfortably accommodates two people\n- Durable and waterproof materials for reliable protection against the elements\n- Easy and quick setup with color-coded poles and intuitive design\n- Two large doors for convenient entry and exit\n- Vestibules provide extra storage space for gear\n- Mesh panels for enhanced ventilation and reduced condensation\n- Rainfly included for added weather protection\n- Freestanding design allows for versatile placement\n- Multiple interior pockets for organizing small items\n- Reflective guy lines and stake points for improved visibility at night\n- Compact and lightweight for easy transportation and storage\n- Double-stitched seams for increased durability\n- Comes with a carrying bag for convenient portability\n\n## Technical Specs\n\n- **Best Use**: Camping, Hiking\n- **Capacity**: 2-person\n- **Seasons**: 3-season\n- **Packed Weight**: Approx. 8 lbs\n- **Number of Doors**: 2\n- **Number of Vestibules**: 2\n- **Vestibule Area**: Approx. 8 square feet per vestibule\n- **Rainfly**: Included\n- **Pole Material**: Lightweight aluminum\n- **Freestanding**: Yes\n- **Footprint Included**: No\n- **Tent Bag Dimensions**: 7ft x 5ft x 4ft\n- **Packed Size**: Compact\n- **Color:** Blue\n- **Warranty**: Manufacturer's warranty included\n\n## User Guide/Manual\n\n1. Tent Components\n\nThe SkyView 2-Person Tent includes the following components:\n- Tent body\n- Rainfly\n- Aluminum tent poles\n- Tent stakes\n- Guy lines\n- Tent bag\n\n2. Tent Setup\n\nFollow these steps to set up your SkyView 2-Person Tent:\n\nStep 1: Find a suitable camping site with a level ground and clear of debris.\nStep 2: Lay out the tent body on the ground, aligning the doors and vestibules as desired.\nStep 3: Assemble the tent poles and insert them into the corresponding pole sleeves or grommets on the tent body.\nStep 4: Attach the rainfly over the tent body, ensuring a secure fit.\nStep 5: Stake down the tent and rainfly using the provided tent stakes, ensuring a taut pitch.\nStep 6: Adjust the guy lines as needed to enhance stability and ventilation.\nStep 7: Once the tent is properly set up, organize your gear inside and enjoy your camping experience.\n\n3. Tent Takedown\n\nTo dismantle and pack up your SkyView 2-Person Tent, follow these steps:\n\nStep 1: Remove all gear and belongings from the tent.\nStep 2: Remove the stakes and guy lines from the ground.\nStep 3: Detach the rainfly from the tent body.\nStep 4: Disassemble the tent poles and remove them from the tent body.\nStep 5: Fold and roll up the tent body, rainfly, and poles separately.\nStep 6: Place all components back into the tent bag, ensuring a compact and organized packing.\n\n4. Tent Care and Maintenance\n\nTo extend the lifespan of your SkyView 2-Person Tent, follow these care and maintenance guidelines:\n\n- Always clean and dry the tent before storing it.\n- Avoid folding or storing the tent when it is wet or damp to prevent mold or mildew growth.\n- Use a mild soap and water solution to clean the tent if necessary, and avoid using harsh chemicals or solvents.\n- Inspect the tent regularly for any damages such as tears, punctures, or broken components. Repair or replace as needed.\n- Store the tent in a cool, dry place away from direct sunlight and extreme temperatures.\n- Avoid placing sharp objects or excessive weight on the tent, as this may cause damage.\n- Follow the manufacturer's recommendations for seam sealing or re-waterproofing the tent if necessary.\n\n5. Safety Precautions\n\n- Always choose a safe and suitable camping location, considering factors such as terrain, weather conditions, and potential hazards.", 'url': 'product_ ...
# getting result...
# result: **Explore CONTOSO's Premium Tents Collection**
#
# At CONTOSO, we know that the right tent can make all the difference in your outdoor adventures. Whether you're embarking on a solo hike, a couple's getaway, or a family camping trip, our high-quality tents are designed to provide comfort, durability, and ease of use. Discover the perfect tent for your next adventure below!
#
# ---
#
# ### **SkyView 2-Person Tent**
# **Price:** $200
# **Brand:** OutdoorLiving
#
# Compact, lightweight, and built for adventure, the SkyView 2-Person Tent is your ultimate companion for camping and hiking. With its spacious interior, waterproof materials, and intuitive setup, this 3-season tent ensures you stay comfortable and protected in the great outdoors.
#
# **Key Features:**
# - Fits 2 people comfortably
# - Waterproof and durable materials
# - Quick setup with color-coded poles
# - Dual doors and vestibules for convenience and storage
# - Enhanced ventilation with mesh panels
#
# **Perfect for:** Couples or friends seeking a reliable, easy-to-carry tent for their outdoor escapades.
#
# [**Shop Now**](#)
#
# ---
#
# ### **TrailMaster X4 Tent**
# **Price:** $250
# **Brand:** OutdoorLiving
#
# Designed for families or groups, the TrailMaster X4 Tent offers a spacious interior and superior weather protection. With its freestanding design, multiple doors, and included rainfly, this 4-person tent is perfect for creating unforgettable camping memories.
#
# **Key Features:**
# - Accommodates up to 4 people
# - Water-resistant with a 2000mm rainfly
# - 6-foot peak height for added comfort
# - Reflective guy lines for nighttime visibility
# - Interior pockets and gear loft for organization
#
# **Perfect for:** Families or small groups looking for a roomy, durable tent for their next camping trip.
#
# [**Shop Now**](#)
#
# ---
#
# **Why Choose CONTOSO Tents?**
# - **Durability You Can Trust:** Built with premium materials to withstand the elements.
# - **Easy Setup:** Intuitive designs make pitching your tent a breeze.
# - **Comfortable Features:** Thoughtfully designed interiors for a cozy outdoor experience.
# - **Adventure-Ready:** Lightweight and portable for all your journeys.
#
# Gear up for your next adventure with CONTOSO's exceptional tents. Browse our collection and find the perfect fit for your outdoor lifestyle!
# question: Create the textual assets for the sleeping bags web page
# embedding done
# index name: products-catalog
# context: [{'id': 'cHJvZHVjdF9pbmZvXzE0Lm1kMA==', 'title': 'Information about product item_number: 14', 'content': '# Information about product item_number: 14\n\n# Information about product item_number: 14\nMountainDream Sleeping Bag, price $130,\n\n## Brand\nMountainDream\n\n## Category\nSleeping Bags\n\n## Features\n- Temperature Rating: Suitable for 3-season camping (rated for temperatures between 15°F to 30°F)\n- Insulation: Premium synthetic insulation for warmth and comfort\n- Shell Material: Durable and water-resistant ripstop nylon\n- Lining Material: Soft and breathable polyester fabric\n- Zipper: Smooth and snag-free YKK zipper with anti-snag design\n- Hood Design: Adjustable hood with drawcord for customized fit and added warmth\n- Draft Tube: Insulated draft tube along the zipper to prevent heat loss\n- Zipper Baffle: Full-length zipper baffle to seal in warmth and block cold drafts\n- Mummy Shape: Contoured mummy shape for optimal heat retention and reduced weight\n- Compression Sack: Included compression sack for compact storage and easy transport\n- Size Options: Available in multiple sizes to accommodate different body types\n- Weight: Lightweight design for backpacking and outdoor adventures\n- Durability: Reinforced stitching and construction for long-lasting durability\n- Extra Features: Interior pocket for storing small essentials, hanging loops for airing out the sleeping bag\n\n## Technical Specs\n\n- **Temperature Rating**: 15°F to 30°F\n- **Insulation**: Premium synthetic insulation\n- **Color:** Green\n- **Shell Material**: Durable and water-resistant ripstop nylon\n- **Lining Material**: Soft and breathable polyester fabric\n- **Zipper**: YKK zipper with anti-snag design\n- **Hood Design**: Adjustable hood with drawcord\n- **Draft Tube**: Insulated draft tube along the zipper\n- **Zipper Baffle**: Full-length zipper baffle\n- **Shape**: Mummy shape\n- **Compression Sack**: Included\n- **Sizes Available**: Multiple sizes available\n- **Weight**: Varies depending on size, approximately 2.5 lbs\n- **Dimensions (packed)**: 84 in x 32 in\n- **Gender**: Unisex\n- **Recommended Use**: Hiking, camping, backpacking\n- **Price**: $130\n\n## User Guide/Manual\n\n### 1. Unpacking and Inspection:\nUpon receiving your sleeping bag, carefully remove it from the packaging. Inspect the sleeping bag for any damage or defects. If you notice any issues, please contact our customer care (contact information provided in Section 8).\n\n### 2. Proper Use:\n- Before using the sleeping bag, make sure to read and understand the user guide.\n- Ensure the sleeping bag is clean and dry before each use.\n- Insert yourself into the sleeping bag, ensuring your body is fully covered.\n- Adjust the hood using the drawcord to achieve a snug fit around your head for added warmth.\n- Use the zipper to open or close the sleeping bag according to your comfort level.\n- Keep the sleeping bag zipped up to maximize insulation during colder temperatures.\n- Avoid placing sharp objects inside the sleeping bag to prevent punctures or damage.\n\n### 3. Temperature Rating and Comfort:\nThe MountainDream Sleeping Bag is rated for temperatures between 15°F to 30°F. However, personal comfort preferences may vary. It is recommended to use additional layers or adjust ventilation using the zipper and hood to achieve the desired temperature.\n\n### 4. Sleeping Bag Care:\n- Spot clean any spills or stains on the sleeping bag using a mild detergent and a soft cloth.\n- If necessary, hand wash the sleeping bag in cold water with a gentle detergent. Rinse thoroughly and air dry.\n- Avoid using bleach or harsh chemicals, as they can damage the materials.\n- Do not dry clean the sleeping bag, as it may affect its performance.\n- Regularly inspect the sleeping bag for signs of wear and tear. Repair or replace any damaged parts as needed.\n\n### 5. Storage:\n- Before storing the sleeping bag, ensure it is clean and completely dry to prevent mold or mildew.\n- Sto ...
# getting result...
# result: **MountainDream Sleeping Bag – Your Ultimate Outdoor Companion**
#
# Experience unmatched comfort and warmth on your outdoor adventures with the MountainDream Sleeping Bag, available now at CONTOSO for just $130. Designed for 3-season camping, this sleeping bag is packed with features to ensure a cozy night under the stars.
#
# ### Key Features:
# - **3-Season Versatility**: Temperature rating of 15°F to 30°F, perfect for spring, summer, and fall adventures.
# - **Premium Insulation**: Stay warm with high-quality synthetic insulation that delivers exceptional heat retention.
# - **Durable & Water-Resistant**: Ripstop nylon shell with a DWR finish protects against moisture and wear.
# - **Snug Comfort**: Soft polyester lining and an adjustable hood with a drawcord for a tailored fit.
# - **Smart Design**: Mummy shape, insulated draft tube, and full-length zipper baffle to lock in warmth.
# - **Lightweight & Portable**: Weighing just 2.5 lbs and packing down to a compact size with the included compression sack.
# - **Extra Details**: Interior pocket for small essentials and hanging loops for easy airing out.
#
# ### Why Choose MountainDream?
# Whether you're hiking, camping, or backpacking, the MountainDream Sleeping Bag is built to perform. Its lightweight design, reinforced stitching, and thoughtful features make it a reliable choice for outdoor enthusiasts. Available in multiple sizes to ensure a perfect fit for everyone.
#
# ### Customer Reviews:
# ⭐️⭐️⭐️⭐️⭐️ "Exceeded my expectations! Warm, comfortable, and easy to pack. Highly recommended!"
# ⭐️⭐️⭐️⭐️ "Great for backpacking—lightweight and compact. The hood design adds extra comfort on cold nights."
# ⭐️⭐️⭐️ "Decent for casual camping, but a bit bulky for long hikes. Insulation works well, though!"
#
# ### Shop with Confidence:
# - **Warranty**: Covers stitching, zippers, insulation, and more.
# - **Flexible Returns**: Return within 30–90 days, depending on your CONTOSO membership level.
#
# Upgrade your camping gear today with the MountainDream Sleeping Bag, exclusively at CONTOSO. Don’t let the cold keep you from your next adventure—order now and sleep soundly wherever the trail takes you!
# question: Draft the website copy for the hiking shoes web page
# embedding done
# index name: products-catalog
# context: [{'id': 'cHJvZHVjdF9pbmZvXzExLm1kMg==', 'title': 'Information about product item_number: 11', 'content': "# Information about product item_number: 11\n\n**Review:** I have mixed feelings about the TrailWalker Hiking Shoes. On the positive side, they offer decent support and have good traction on most terrains. However, I found the sizing to be slightly off, and the shoes took a bit of breaking in before they felt comfortable. Also, while they are durable overall, I noticed some minor wear and tear on the outsole after a few months of regular use. They are a decent choice for occasional hikers but may not be ideal for intense or prolonged expeditions.\n\n4) **Rating:** 4\n   **Review:** I purchased the TrailWalker Hiking Shoes for a hiking trip in rugged mountain terrain. They performed admirably, providing excellent stability and protection. The waterproofing feature kept my feet dry during unexpected rain showers. The shoes are also lightweight, which is a bonus for long hikes. However, I did notice a small amount of discomfort around the toe area after extended periods of walking. Nevertheless, these shoes are a reliable option for most hiking adventures.\n\n5) **Rating:** 5\n   **Review:** The TrailWalker Hiking Shoes are hands down the best hiking shoes I've ever owned. From the moment I put them on, they felt like a perfect fit. The traction is outstanding, allowing me to confidently navigate challenging trails without slipping. The shoes provide excellent ankle support, which is crucial on uneven terrain. They are also durable and show no signs of wear, even after multiple hikes. I can't recommend these shoes enough for avid hikers. They are worth every penny.\n\n## FAQ\n49) How long does it take to break in the TrailWalker Hiking Shoes?\n   The TrailWalker Hiking Shoes are made of flexible synthetic materials, so they usually take just a few days of regular use to break in and feel comfortable on your feet.\n\n50) Are the TrailWalker Hiking Shoes suitable for trail running?\n   While the TrailWalker Hiking Shoes are designed primarily for hiking, their lightweight construction and excellent traction also make them suitable for trail running on moderate terrains.\n\n51) Do the TrailWalker Hiking Shoes provide good arch support?\n   Yes, the TrailWalker Hiking Shoes feature a cushioned midsole and supportive insole, providing excellent arch support for long hikes and reducing foot fatigue.\n\n52) Are the TrailWalker Hiking Shoes compatible with gaiters?\n   Yes, the TrailWalker Hiking Shoes can be used with most standard gaiters, providing additional protection against water, snow, and debris while hiking.\n\n53) Can the TrailWalker Hiking Shoes be resoled?\n   While it may be possible to resole the TrailWalker Hiking Shoes, we recommend contacting the manufacturer (TrekReady) or a professional shoe repair service to determine the feasibility and cost of resoling.", 'url': 'product_info_11.md'}, {'id': 'cHJvZHVjdF9pbmZvXzExLm1kMQ==', 'title': 'Information about product item_number: 11', 'content': '# Information about product item_number: 11\n\n9. **Do not share footwear**\n10. **Do not ignore manufacturer\'s instructions**\n\n## Warranty Information\nPlease read the following warranty information carefully.\n\n1. Warranty Coverage:\n   - The TrailWalker Hiking Shoes are covered by a limited manufacturer\'s warranty.\n   - The warranty covers defects in materials and workmanship under normal use and conditions.\n   - The warranty is valid for a period of [insert duration] from the date of purchase.\n\n2. Warranty Claims:\n   - To initiate a warranty claim, please contact our customer care team at the following contact details:\n      - Customer Care: TrailWalker Gear\n      - Email: customerservice@trailwalkergear.com\n      - Phone: 1-800-123-4567\n\n3. Warranty Exclusions:\n   - The warranty does not cover damage resulting from misuse, neglect, accidents, improper care, or unauthorized repairs.\n   - Normal wea ...
# getting result...
# [2025-05-06 15:15:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-05-06 15:15:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-05-06 15:15:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_relevance_20250506_151552_027315, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250506_151552_027315/logs.txt
# [2025-05-06 15:15:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-05-06 15:15:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_coherence_20250506_151552_028578, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_coherence_20250506_151552_028578/logs.txt
# [2025-05-06 15:15:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-05-06 15:15:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_fluency_20250506_151552_028047, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250506_151552_028047/logs.txt
# [2025-05-06 15:15:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_groundedness_20250506_151552_029751, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_groundedness_20250506_151552_029751/logs.txt
# result: **TrailWalker Hiking Shoes – Adventure Awaits!**
#
# Step into the great outdoors with confidence in the TrailWalker Hiking Shoes from CONTOSO. Designed by TrekReady, these premium hiking shoes combine durability, comfort, and performance to elevate your outdoor adventures. Whether you're tackling rugged trails or exploring serene landscapes, TrailWalker has you covered.
#
# ### Key Features:
# - **Durable & Waterproof**: Built to withstand tough terrains and unpredictable weather.
# - **Exceptional Grip**: Traction outsole with multidirectional lugs for stability on any surface.
# - **All-Day Comfort**: Cushioned insole, supportive midsole, and padded collar ensure a comfortable fit for long hikes.
# - **Breathable Design**: Synthetic leather and mesh keep your feet cool and dry.
# - **Lightweight Construction**: Reduce fatigue and hike farther with ease.
# - **Quick-Lace System**: Adjust your fit effortlessly for a secure and snug feel.
# - **Enhanced Protection**: Reinforced toe cap, heel, and mudguard shield your feet from debris.
# - **Reflective Accents**: Stay visible during low-light adventures.
#
# ### Why Choose TrailWalker?
# TrailWalker Hiking Shoes are crafted for outdoor enthusiasts who demand reliability and performance. With features like waterproofing, arch support, and compatibility with gaiters, these shoes are perfect for hiking, trekking, and trail running on moderate terrains.
#
# ### Available Sizes:
# Choose from US sizes 7-12, with multiple widths for the perfect fit.
#
# ### Price:
# $110 – A worthy investment for your next adventure.
#
# ### Warranty & Returns:
# Enjoy peace of mind with TrekReady’s limited warranty covering defects in materials and workmanship. CONTOSO members also benefit from flexible return policies based on membership tier.
#
# ### Ready to Explore?
# Gear up with TrailWalker Hiking Shoes and make every step count. Order now and experience the ultimate blend of comfort, durability, and style for your outdoor pursuits!
# 2025-05-06 15:15:52 +0000   33621 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-05-06 15:15:57 +0000   33621 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-05-06 15:15:57 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 5.54 seconds. Estimated time for incomplete lines: 11.08 seconds.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 3.16 seconds. Estimated time for incomplete lines: 3.16 seconds.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 2.14 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_relevance_20250506_151552_027315"
# Run status: "Completed"
# Start time: "2025-05-06 15:15:52.036719+00:00"
# Duration: "0:00:07.202731"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250506_151552_027315"
#
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 2.35 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 2.42 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 2.44 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-05-06 15:15:52 +0000   33621 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 6.83 seconds. Estimated time for incomplete lines: 13.66 seconds.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 3.46 seconds. Estimated time for incomplete lines: 3.46 seconds.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 2.35 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_groundedness_20250506_151552_029751"
# Run status: "Completed"
# Start time: "2025-05-06 15:15:52.038518+00:00"
# Duration: "0:00:08.211763"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_groundedness_20250506_151552_029751"
#
# 2025-05-06 15:15:52 +0000   33621 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 6.41 seconds. Estimated time for incomplete lines: 12.82 seconds.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 3.48 seconds. Estimated time for incomplete lines: 3.48 seconds.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 2.44 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_fluency_20250506_151552_028047"
# Run status: "Completed"
# Start time: "2025-05-06 15:15:52.043749+00:00"
# Duration: "0:00:08.228180"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250506_151552_028047"
#
# 2025-05-06 15:15:52 +0000   33621 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-05-06 15:15:57 +0000   33621 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-05-06 15:15:57 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 5.73 seconds. Estimated time for incomplete lines: 11.46 seconds.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-05-06 15:15:58 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 3.24 seconds. Estimated time for incomplete lines: 3.24 seconds.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-05-06 15:15:59 +0000   33621 execution.bulk     INFO     Average execution time for completed lines: 2.42 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_coherence_20250506_151552_028578"
# Run status: "Completed"
# Start time: "2025-05-06 15:15:52.039774+00:00"
# Duration: "0:00:08.258773"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_coherence_20250506_151552_028578"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:07.202731",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250506_151552_027315"
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:08.228180",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250506_151552_028047"
#     },
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:00:08.258773",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_coherence_20250506_151552_028578"
#     },
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:08.211763",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_groundedness_20250506_151552_029751"
#     }
# }
#
# ====================================================
#
# Evaluation results saved to "/workspaces/aitour-concept-to-creation-ai-studio/src/web_designer_app/eval_results.jsonl".
# -----Summarized Metrics-----
# {'relevance.relevance': 4.666666666666667, 'relevance.gpt_relevance': 4.666666666666667, 'relevance.relevance_threshold': 3.0, 'fluency.fluency': 4.0, 'fluency.gpt_fluency': 4.0, 'fluency.fluency_threshold': 3.0, 'coherence.coherence': 5.0, 'coherence.gpt_coherence': 5.0, 'coherence.coherence_threshold': 3.0, 'groundedness.groundedness': 5.0, 'groundedness.gpt_groundedness': 5.0, 'groundedness.groundedness_threshold': 3.0, 'relevance.binary_aggregate': 1.0, 'fluency.binary_aggregate': 1.0, 'coherence.binary_aggregate': 1.0, 'groundedness.binary_aggregate': 1.0}
# -----Tabular Result-----

# %%
eval_result = pd.DataFrame(result_eval["rows"])
print("-----Summarized Metrics-----")
print(result_eval["metrics"])
print("-----Tabular Result-----")
eval_result.head()
# Out:
#                                         inputs.query  \
# 0  Create the website copy for the tents catalog ...
# 1  Create the textual assets for the sleeping bag...
# 2  Draft the website copy for the hiking shoes we...
#
#                                       inputs.context  \
# 0  ## Task\nYou serve as a web copywriter for the...
# 1  ## Task\nYou serve as a web copywriter for the...
# 2  ## Task\nYou serve as a web copywriter for the...
#
#                                      inputs.response  \
# 0  **Explore CONTOSO's Premium Tents Collection**...
# 1  **MountainDream Sleeping Bag – Your Ultimate O...
# 2  **TrailWalker Hiking Shoes – Adventure Awaits!...
#
#    outputs.relevance.relevance  outputs.relevance.gpt_relevance  \
# 0                            4                                4
# 1                            5                                5
# 2                            5                                5
#
#                   outputs.relevance.relevance_reason  \
# 0  The RESPONSE is a complete and detailed catalo...
# 1  The RESPONSE is comprehensive, directly addres...
# 2  The RESPONSE fully addresses the QUERY with de...
#
#   outputs.relevance.relevance_result  outputs.relevance.relevance_threshold  \
# 0                               pass                                      3
# 1                               pass                                      3
# 2                               pass                                      3
#
#    outputs.fluency.fluency  outputs.fluency.gpt_fluency  ...  \
# 0                        4                            4  ...
# 1                        4                            4  ...
# 2                        4                            4  ...
#
#   outputs.coherence.gpt_coherence  \
# 0                               5
# 1                               5
# 2                               5
#
#                   outputs.coherence.coherence_reason  \
# 0  The RESPONSE is well-structured, logically org...
# 1  The RESPONSE provides a detailed and well-stru...
# 2  The RESPONSE is well-structured, directly addr...
#
#    outputs.coherence.coherence_result  outputs.coherence.coherence_threshold  \
# 0                                pass                                      3
# 1                                pass                                      3
# 2                                pass                                      3
#
#    outputs.groundedness.groundedness outputs.groundedness.gpt_groundedness  \
# 0                                  5                                     5
# 1                                  5                                     5
# 2                                  5                                     5
#
#             outputs.groundedness.groundedness_reason  \
# 0  The RESPONSE is fully grounded and complete as...
# 1  The RESPONSE accurately reflects the CONTEXT b...
# 2  The RESPONSE is well-grounded in the CONTEXT, ...
#
#    outputs.groundedness.groundedness_result  \
# 0                                      pass
# 1                                      pass
# 2                                      pass
#
#    outputs.groundedness.groundedness_threshold  line_number
# 0                                            3            0
# 1                                            3            1
# 2                                            3            2
#
# [3 rows x 24 columns]

# %%
# Get the link to visualize eval results to Azure AI Studio
result_eval["studio_url"]
# Out:
# 'https://ai.azure.com/build/evaluation/b396827e-393c-47fe-8851-68e9cbae1f15?wsid=/subscriptions/6415ebd4-1dd7-430f-bd4d-2f5e9419c1cd/resourceGroups/BRK441-7670_RG/providers/Microsoft.MachineLearningServices/workspaces/BRK441-7670-project'
