# %% [markdown]
# # Evaluating generation quality performance metrics of the flow

# %%
# Configuring Azure OpenAI service connection

import os
from dotenv import load_dotenv
load_dotenv()

# Initialize Azure OpenAI Connection
model_config = {
        "azure_deployment": "gpt-4",
        "api_version": os.environ["AZURE_OPENAI_API_VERSION"],
        "azure_endpoint": os.environ["AZURE_OPENAI_ENDPOINT"],
        "api_key": os.environ["AZURE_OPENAI_KEY"]
}

# %%
# Uploading test dataset
import pandas as pd

test_data_path = "../data/test_dataset.jsonl"

df = pd.read_json(test_data_path, lines=True)
df.head()
# Out:
#                                             question
# 0  Create the website copy for the tents catalog ...
# 1  Create the textual assets for the sleeping bag...
# 2  Draft the website copy for the hiking shoes we...

# %%
# Importing class evaluators 
from create_website_copy_request import get_response
from azure.ai.evaluation import RelevanceEvaluator, GroundednessEvaluator, FluencyEvaluator, CoherenceEvaluator, evaluate

relevance_evaluator = RelevanceEvaluator(model_config)
groundedness_evaluator = GroundednessEvaluator(model_config)
fluency_evaluator = FluencyEvaluator(model_config)
coherence_evaluator = CoherenceEvaluator(model_config)

# %%
# Create unique id for each run with date and time
from datetime import datetime
run_id = datetime.now().strftime("%Y%m%d%H%M%S")
run_id = f"{run_id}_chat_evaluation_sdk"    
print(run_id)
# Out:
# 20241127064509_chat_evaluation_sdk

# %%
subscription_id = os.environ["AZURE_SUBSCRIPTION_ID"]
resource_group_name= os.environ["AZURE_RESOURCE_GROUP"]
project_name = os.environ["AZURE_AI_PROJECT_NAME"]

azure_ai_project = {
    "subscription_id": subscription_id,
    "resource_group_name": resource_group_name,
    "project_name": project_name
}

# %%
import json

def create_response_data(df):
    results = []

    for index, row in df.iterrows():
        question = row['question']
        
        # Run get response
        response = get_response(question)
                
        # Add results to list
        result = {
            'query': question,
            'context': response["context"],
            'response': response["answer"]
        }
        results.append(result)

    # Save results to a JSONL file
    with open('run_results.jsonl', 'w') as file:
        for result in results:
            file.write(json.dumps(result) + '\n')
    return results

# %%
# Step 1: Run web_designer_app against test dataset
# Step 2: Evaluate outputs (answer and context) against generation quality metrics
# %pip install azure-ai-evaluation[remote]
response_results = create_response_data(df)
result_eval = evaluate(
    evaluation_name=run_id,
    data="run_results.jsonl",
    evaluators={
        "relevance": relevance_evaluator,
        "fluency": fluency_evaluator,
        "coherence": coherence_evaluator,
        "groundedness": groundedness_evaluator,
    },
    # column mapping    
    evaluator_config={
        "default": {
            "query": "${data.query}",
            "response": "${data.response}",
            "context": "${data.context}",
        },
    },
    azure_ai_project = azure_ai_project, # comment this line if you don't want to push results to your Azure AI Project
    output_path="./eval_results.jsonl"
)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-ai-evaluation[remote] in /usr/local/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: promptflow-devkit>=1.15.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.16.2)
# Requirement already satisfied: promptflow-core>=1.15.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.16.2)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (2.10.0)
# Requirement already satisfied: azure-identity>=1.16.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.19.0)
# Requirement already satisfied: azure-core>=1.30.2 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.32.0)
# Requirement already satisfied: nltk>=3.9.1 in /usr/local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (3.9.1)
# Requirement already satisfied: promptflow-azure<2.0.0,>=1.15.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation[remote]) (1.16.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.11/site-packages (from azure-core>=1.30.2->azure-ai-evaluation[remote]) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/site-packages (from azure-core>=1.30.2->azure-ai-evaluation[remote]) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/site-packages (from azure-core>=1.30.2->azure-ai-evaluation[remote]) (4.12.2)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.11/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation[remote]) (43.0.3)
# Requirement already satisfied: msal>=1.30.0 in /usr/local/lib/python3.11/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation[remote]) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.11/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation[remote]) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation[remote]) (4.67.1)
# Requirement already satisfied: azure-ai-ml<2.0.0,>=1.14.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.22.4)
# Requirement already satisfied: azure-cosmos<5.0.0,>=4.5.1 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (4.9.0)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (12.24.0)
# Requirement already satisfied: docstring_parser in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.115.5)
# Requirement already satisfied: filetype>=1.2.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (3.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (4.23.0)
# Requirement already satisfied: promptflow-tracing==1.16.2 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (1.16.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (5.9.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /usr/local/lib/python3.11/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.18.6)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (1.55.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /usr/local/lib/python3.11/site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (1.28.2)
# Requirement already satisfied: tiktoken>=0.4.0 in /usr/local/lib/python3.11/site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.8.0)
# Requirement already satisfied: argcomplete>=3.2.3 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.5.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.0.0b32)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (0.4.6)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.16.1)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (5.0.0)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.1.41)
# Requirement already satisfied: httpx>=0.25.1 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (0.27.2)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.23.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.28.2)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (2.2.3)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (10.4.0)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.0.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (2.0.36)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.0.2)
# Requirement already satisfied: pyyaml>=5.1.0 in /usr/local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (6.0.2)
# Requirement already satisfied: msrest>=0.6.18 in /usr/local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.7.1)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.5.0)
# Requirement already satisfied: azure-storage-file-share in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (12.20.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (12.18.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /usr/local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.1.28)
# Requirement already satisfied: opencensus-ext-azure in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.1.13)
# Requirement already satisfied: opencensus-ext-logging in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.1.1)
# Requirement already satisfied: fixedint==0.1.6 in /usr/local/lib/python3.11/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (0.1.6)
# Requirement already satisfied: opentelemetry-api~=1.26 in /usr/local/lib/python3.11/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.28.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation[remote]) (1.17.1)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /usr/local/lib/python3.11/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.41.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (2.10.2)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (1.9.0)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.11/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (9.0.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (2024.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (6.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (4.0.11)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (4.6.2.post1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.21.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (8.5.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (0.8.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (24.2)
# Requirement already satisfied: portalocker<3,>=1.4 in /usr/local/lib/python3.11/site-packages (from msal-extensions>=1.2.0->azure-identity>=1.16.0->azure-ai-evaluation[remote]) (2.10.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in /usr/local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in /usr/local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.28.2)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.11/site-packages (from opentelemetry-proto==1.28.2->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (5.28.3)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (2.1.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation[remote]) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation[remote]) (2.2.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.11/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.2.12)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.1.1)
# Requirement already satisfied: aiohttp>=3.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (3.11.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation[remote]) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (5.0.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from Jinja2>=3.1.2->flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (3.0.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.11/site-packages (from msrest>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (2.0.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /usr/local/lib/python3.11/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.49b2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (2.27.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation[remote]) (10.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation[remote]) (0.8.0)
# Requirement already satisfied: opencensus<1.0.0,>=0.11.4 in /home/vscode/.local/lib/python3.11/site-packages (from opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.11.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /home/vscode/.local/lib/python3.11/site-packages (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (3.2.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/vscode/.local/lib/python3.11/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /home/vscode/.local/lib/python3.11/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (2.36.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/vscode/.local/lib/python3.11/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/vscode/.local/lib/python3.11/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/vscode/.local/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure<2.0.0,>=1.15.0->azure-ai-evaluation[remote]) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# question: Create the website copy for the tents catalog page
# embedding done
# index name: products-catalog
# context: [{'id': 'cHJvZHVjdF9pbmZvXzgubWQw', 'title': 'Information about product item_number: 8', 'content': '# Information about product item_number: 8\n\n# Information about product item_number: 8\nAlpine Explorer Tent, price $350,\n\n## Brand\nAlpineGear\n\n## Category\nTents\n\n### Features\n- Waterproof: Provides reliable protection against rain and moisture.\n- Easy Setup: Simple and quick assembly process, making it convenient for camping.\n- Room Divider: Includes a detachable divider to create separate living spaces within the tent.\n- Excellent Ventilation: Multiple mesh windows and vents promote airflow and reduce condensation.\n- Gear Loft: Built-in gear loft or storage pockets for organizing and storing camping gear.\n\n## Technical Specs\n**Best Use**: Camping  \n**Capacity**: 8-person  \n**Season Rating**: 3-season  \n**Setup**: Freestanding  \n**Material**: Polyester  \n**Waterproof**: Yes  \n**Floor Area**: 120 square feet  \n**Peak Height**: 6.5 feet  \n**Number of Doors**: 2  \n**Color**: Orange  \n**Rainfly**: Included  \n**Rainfly Waterproof Rating**: 3000mm  \n**Tent Poles**: Aluminum  \n**Pole Diameter**: 12mm  \n**Ventilation**: Mesh panels and adjustable vents  \n**Interior Pockets**: 4 pockets  \n**Gear Loft**: Included  \n**Footprint**: Sold separately  \n**Guy Lines**: Reflective  \n**Stakes**: Aluminum  \n**Carry Bag**: Included  \n**Dimensions**: 12ft x 10ft x 7ft (Length x Width x Peak Height)  \n**Packed Size**: 24 inches x 10 inches  \n**Weight**: 17 lbs\n\n## Alpine Explorer Tent User Guide\n\nThank you for choosing the Alpine Explorer Tent. This user guide provides instructions on how to set up, use, and maintain your tent effectively. Please read this guide thoroughly before using the tent.\n\n### Package Contents\n\nEnsure that the package includes the following components:\n\n- Alpine Explorer Tent body\n- Tent poles\n- Rainfly\n- Stakes and guy lines\n- Carry bag\n- User Guide\n\nIf any components are missing or damaged, please contact our customer support immediately.\n\n### Tent Setup\n\n**Step 1: Selecting a Suitable Location**\n\n- Find a level and clear area for pitching the tent.\n- Remove any sharp objects or debris that could damage the tent floor.\n\n**Step 2: Unpacking and Organizing Components**\n\n- Lay out all the tent components on the ground.\n- Familiarize yourself with each part, including the tent body, poles, rainfly, stakes, and guy lines.\n\n**Step 3: Assembling the Tent Poles**\n\n- Connect the tent poles according to their designated color codes or numbering.\n- Slide the connected poles through the pole sleeves or attach them to the tent body clips.\n\n**Step 4: Setting up the Tent Body**\n\n- Begin at one end and raise the tent body by pushing up the poles.\n- Ensure that the tent body is evenly stretched and centered.\n- Secure the tent body to the ground using stakes and guy lines as needed.\n\n**Step 5: Attaching the Rainfly**\n\n- Spread the rainfly over the tent body.\n- Attach the rainfly to the tent corners and secure it with the provided buckles or clips.\n- Adjust the tension of the rainfly to ensure proper airflow and weather protection.\n\n**Step 6: Securing the Tent**\n\n- Stake down the tent corners and guy out the guy lines for additional stability.\n- Adjust the tension of the guy lines to provide optimal stability and wind resistance.\n\n### Tent Takedown and Storage\n\n**Step 1: Removing Stakes and Guy Lines**\n\n- Remove all stakes from the ground.\n- Untie or disconnect the guy lines from the tent and store them separately.\n\n**Step 2: Taking Down the Tent Body**\n\n- Start by collapsing the tent poles carefully.\n- Remove the poles from the pole sleeves or clips.\n- Collapse the tent body and fold it neatly.\n\n**Step 3: Disassembling the Tent Poles**\n\n- Disconnect and separate the individual pole sections.', 'url': 'product_info_8.md'}, {'id': 'cHJvZHVjdF9pbmZvXzE1Lm1kMA==', 'title': 'Information about product item_number: 15', 'content': " ...
# getting result...
# result: Welcome to the CONTOSO Outdoor Tents Collection, where adventure meets comfort! Whether you're planning a solo escape or a family camping trip, our range of high-quality tents has you covered. Explore our selection and find the perfect tent for your next outdoor adventure.
#
# ### Alpine Explorer Tent - $350
# **Brand:** AlpineGear
# **Capacity:** 8-person
# **Features:** Waterproof, easy setup, room divider, excellent ventilation, gear loft
# **Description:** Experience the great outdoors with the Alpine Explorer Tent. Designed for up to 8 people, this tent offers a spacious interior with a detachable room divider for added privacy. Its waterproof construction and excellent ventilation ensure a comfortable stay, rain or shine. The built-in gear loft and storage pockets keep your camping essentials organized. Perfect for family camping trips, this tent promises convenience and comfort.
#
# ### SkyView 2-Person Tent - $200
# **Brand:** OutdoorLiving
# **Capacity:** 2-person
# **Features:** Spacious interior, waterproof, easy setup, two large doors, vestibules
# **Description:** The SkyView 2-Person Tent is your go-to for intimate camping experiences. With its durable and waterproof materials, this tent provides reliable protection against the elements. The easy setup, thanks to color-coded poles, and the spacious interior make it a favorite among campers. Enjoy the convenience of two large doors and extra storage space with vestibules. Lightweight and compact, it's perfect for hiking and camping adventures.
#
# ### TrailMaster X4 Tent - $250
# **Brand:** OutdoorLiving
# **Capacity:** 4-person
# **Features:** Durable polyester, water-resistant, easy setup, multiple doors, mesh panels
# **Description:** Discover the TrailMaster X4 Tent, designed for those who love the outdoors. This 4-person tent offers a spacious interior and is crafted from durable polyester to withstand light rain. The easy setup and multiple doors provide convenience, while mesh panels ensure ventilation and insect protection. With reflective guy lines for nighttime visibility and a freestanding design, this tent is ready for any camping adventure.
#
# At CONTOSO, we are committed to providing you with the best outdoor gear to enhance your camping experience. Choose your perfect tent today and embark on your next adventure with confidence!
# question: Create the textual assets for the sleeping bags web page
# embedding done
# index name: products-catalog
# context: [{'id': 'cHJvZHVjdF9pbmZvXzcubWQy', 'title': 'Information about product item_number: 7', 'content': '# Information about product item_number: 7\n\nThe CozyNights Sleeping Bag is rated for 3-season use and has a temperature rating of 20�F to 60�F (-6�C to 15�C).\n\n32) Can the CozyNights Sleeping Bag be zipped together with another sleeping bag to create a double sleeping bag?\n   Yes, two CozyNights Sleeping Bags can be zipped together to create a double sleeping bag, provided they have compatible zippers.\n\n33) Does the CozyNights Sleeping Bag have a draft collar or draft tube?\n   The CozyNights Sleeping Bag features a draft tube along the zipper to help prevent cold air from entering and warm air from escaping.', 'url': 'product_info_7.md'}, {'id': 'cHJvZHVjdF9pbmZvXzcubWQw', 'title': 'Information about product item_number: 7', 'content': "# Information about product item_number: 7\n\n# Information about product item_number: 7\nCozyNights Sleeping Bag, price $100,\n\n## Brand\nCozyNights\n\n## Category\nSleeping Bags\n\n## Features\n- **Lightweight**: Designed to be lightweight for easy carrying during outdoor adventures.\n- **3-Season**: Suitable for use in spring, summer, and fall seasons.\n- **Compact Design**: Folds down to a compact size for convenient storage and transport.\n- **Included Stuff Sack**: Comes with a stuff sack for easy packing and carrying.\n- **Insulation**: Provides warmth and comfort during sleep.\n- **Zipper Closure**: Features a durable zipper closure for easy access and temperature control.\n- **Hood**: Equipped with a hood to keep your head warm and protected.\n- **Durable Construction**: Made with high-quality materials for long-lasting durability.\n- **Versatile**: Suitable for various outdoor activities such as camping, hiking, and backpacking.\n- **Comfortable**: Offers a comfortable sleeping experience with ample room and padding.\n- **Temperature Rating**: Provides reliable performance within a specific temperature range.\n\n## Technical Specifications\n- **Material**: Polyester\n- **Color**: Red\n- **Dimensions**: 80 inches x 33 inches (Length x Width)\n- **Weight**: 3.5 lbs\n- **Temperature Rating**: 3.5/5\n- **Comfort Rating**: 4/5\n- **Season Rating**: 3-season\n- **Insulation Type**: Synthetic\n- **Shell Material**: Polyester\n- **Lining Material**: Polyester\n- **Zipper Type**: Full-length zipper\n- **Hood**: Yes\n- **Draft Collar**: Yes\n- **Draft Tube**: Yes\n- **Compression Sack**: Yes\n- **Pillow Pocket**: Yes\n- **Internal Storage Pocket**: Yes\n- **Zipper Baffles**: Yes\n- **Footbox Design**: Contoured\n- **Zipper Compatibility**: Can be zipped together with another sleeping bag\n\n## CozyNights Sleeping Bag User Guide\n\nThank you for choosing the CozyNights Sleeping Bag. This user guide provides instructions on how to use and maintain your sleeping bag effectively. Please read this guide thoroughly before using the sleeping bag.\n\n### Usage Instructions\n\n1. Unpack the sleeping bag and lay it flat on a clean surface.\n2. Open the zipper completely.\n3. Slide into the sleeping bag, ensuring your feet are at the bottom end.\n4. Pull the hood over your head to retain warmth if desired.\n5. Adjust the zipper as needed to control ventilation and temperature.\n6. When not in use, roll the sleeping bag tightly and secure it with the attached straps or use the included stuff sack for compact storage.\n7. For cleaning instructions, refer to the maintenance section below.\n\n### Maintenance\n\n- Spot cleaning: If the sleeping bag gets dirty, gently spot clean the affected area with mild soap and water.\n- Machine washing: If necessary, the sleeping bag can be machine washed in a front-loading machine using a gentle cycle and mild detergent. Follow the manufacturer's instructions for specific care details.\n- Drying: Hang the sleeping bag in a well-ventilated area or use a low heat setting in the dryer. Avoid high heat as it may damage the fabric.\n- Storage: Store the sleepi ...
# getting result...
# result: Welcome to CONTOSO's Sleeping Bags Collection!
#
# ### CozyNights Sleeping Bag - $100
# Experience the perfect blend of comfort and versatility with the CozyNights Sleeping Bag. Designed for 3-season use, this sleeping bag is your ideal companion for spring, summer, and fall adventures. With a temperature rating of 20°F to 60°F (-6°C to 15°C), it ensures warmth and coziness in various conditions.
#
# **Features:**
# - **Lightweight & Compact**: Easy to carry and store, thanks to its compact design and included stuff sack.
# - **Durable Construction**: Made from high-quality polyester for long-lasting use.
# - **Comfort & Insulation**: Enjoy a comfortable sleep with synthetic insulation and a contoured footbox design.
# - **Versatile Use**: Perfect for camping, hiking, and backpacking.
# - **Zipper Compatibility**: Zip two bags together for a double sleeping bag experience.
#
# **Technical Specs:**
# - **Dimensions**: 80" x 33"
# - **Weight**: 3.5 lbs
# - **Color**: Red
#
# ### MountainDream Sleeping Bag - $130
# Elevate your outdoor experience with the MountainDream Sleeping Bag, crafted for those who seek warmth and comfort in cooler climates. Rated for temperatures between 15°F to 30°F, this sleeping bag is perfect for 3-season camping.
#
# **Features:**
# - **Premium Insulation**: Stay warm with high-quality synthetic insulation.
# - **Durable & Water-Resistant**: Made with ripstop nylon to withstand the elements.
# - **Mummy Shape**: Optimized for heat retention and reduced weight.
# - **Adjustable Hood**: Customize your fit for added warmth.
#
# **Technical Specs:**
# - **Dimensions (packed)**: 84" x 32"
# - **Weight**: Approximately 2.5 lbs
# - **Color**: Green
#
# At CONTOSO, we are committed to providing you with top-quality sleeping bags that enhance your outdoor adventures. Whether you're exploring the great outdoors or enjoying a cozy night under the stars, our sleeping bags are designed to meet your needs. Choose CONTOSO for comfort, durability, and reliability on every journey.
# question: Draft the website copy for the hiking shoes web page
# embedding done
# index name: products-catalog
# context: [{'id': 'cHJvZHVjdF9pbmZvXzExLm1kMg==', 'title': 'Information about product item_number: 11', 'content': "# Information about product item_number: 11\n\n**Review:** I have mixed feelings about the TrailWalker Hiking Shoes. On the positive side, they offer decent support and have good traction on most terrains. However, I found the sizing to be slightly off, and the shoes took a bit of breaking in before they felt comfortable. Also, while they are durable overall, I noticed some minor wear and tear on the outsole after a few months of regular use. They are a decent choice for occasional hikers but may not be ideal for intense or prolonged expeditions.\n\n4) **Rating:** 4\n   **Review:** I purchased the TrailWalker Hiking Shoes for a hiking trip in rugged mountain terrain. They performed admirably, providing excellent stability and protection. The waterproofing feature kept my feet dry during unexpected rain showers. The shoes are also lightweight, which is a bonus for long hikes. However, I did notice a small amount of discomfort around the toe area after extended periods of walking. Nevertheless, these shoes are a reliable option for most hiking adventures.\n\n5) **Rating:** 5\n   **Review:** The TrailWalker Hiking Shoes are hands down the best hiking shoes I've ever owned. From the moment I put them on, they felt like a perfect fit. The traction is outstanding, allowing me to confidently navigate challenging trails without slipping. The shoes provide excellent ankle support, which is crucial on uneven terrain. They are also durable and show no signs of wear, even after multiple hikes. I can't recommend these shoes enough for avid hikers. They are worth every penny.\n\n## FAQ\n49) How long does it take to break in the TrailWalker Hiking Shoes?\n   The TrailWalker Hiking Shoes are made of flexible synthetic materials, so they usually take just a few days of regular use to break in and feel comfortable on your feet.\n\n50) Are the TrailWalker Hiking Shoes suitable for trail running?\n   While the TrailWalker Hiking Shoes are designed primarily for hiking, their lightweight construction and excellent traction also make them suitable for trail running on moderate terrains.\n\n51) Do the TrailWalker Hiking Shoes provide good arch support?\n   Yes, the TrailWalker Hiking Shoes feature a cushioned midsole and supportive insole, providing excellent arch support for long hikes and reducing foot fatigue.\n\n52) Are the TrailWalker Hiking Shoes compatible with gaiters?\n   Yes, the TrailWalker Hiking Shoes can be used with most standard gaiters, providing additional protection against water, snow, and debris while hiking.\n\n53) Can the TrailWalker Hiking Shoes be resoled?\n   While it may be possible to resole the TrailWalker Hiking Shoes, we recommend contacting the manufacturer (TrekReady) or a professional shoe repair service to determine the feasibility and cost of resoling.", 'url': 'product_info_11.md'}, {'id': 'cHJvZHVjdF9pbmZvXzExLm1kMQ==', 'title': 'Information about product item_number: 11', 'content': '# Information about product item_number: 11\n\n9. **Do not share footwear**\n10. **Do not ignore manufacturer\'s instructions**\n\n## Warranty Information\nPlease read the following warranty information carefully.\n\n1. Warranty Coverage:\n   - The TrailWalker Hiking Shoes are covered by a limited manufacturer\'s warranty.\n   - The warranty covers defects in materials and workmanship under normal use and conditions.\n   - The warranty is valid for a period of [insert duration] from the date of purchase.\n\n2. Warranty Claims:\n   - To initiate a warranty claim, please contact our customer care team at the following contact details:\n      - Customer Care: TrailWalker Gear\n      - Email: customerservice@trailwalkergear.com\n      - Phone: 1-800-123-4567\n\n3. Warranty Exclusions:\n   - The warranty does not cover damage resulting from misuse, neglect, accidents, improper care, or unauthorized repairs.\n   - Normal wea ...
# getting result...
# [2024-11-27 06:46:23 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-11-27 06:46:23 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_e9uxcbas_20241127_064623_533870, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_e9uxcbas_20241127_064623_533870/logs.txt
# [2024-11-27 06:46:23 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-11-27 06:46:23 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-11-27 06:46:23 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-11-27 06:46:23 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_blpblndj_20241127_064623_536579, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_blpblndj_20241127_064623_536579/logs.txt
# [2024-11-27 06:46:23 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_86jx7imv_20241127_064623_531613, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_86jx7imv_20241127_064623_531613/logs.txt
# [2024-11-27 06:46:23 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gddk70so_20241127_064623_533245, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gddk70so_20241127_064623_533245/logs.txt
# result: **CONTOSO TrailWalker Hiking Shoes**
#
# Embark on your next adventure with confidence in the CONTOSO TrailWalker Hiking Shoes. Designed by TrekReady, these shoes are the perfect companion for hiking enthusiasts seeking durability, comfort, and performance.
#
# **Key Features:**
# - **Durable & Waterproof:** Withstand various terrains and weather conditions with our high-quality synthetic leather and mesh construction.
# - **Superior Traction:** Navigate challenging trails effortlessly with a traction outsole featuring multidirectional lugs.
# - **Enhanced Comfort:** Enjoy long hikes with a cushioned insole, supportive midsole, and padded collar and tongue.
# - **Lightweight Design:** Reduce fatigue on extended adventures with our lightweight construction.
# - **Quick-Lace System:** Easily adjust for a secure fit with our convenient quick-lace system.
# - **Reflective Accents:** Stay visible in low-light conditions for added safety.
#
# **Technical Specs:**
# - **Best Use:** Hiking
# - **Upper Material:** Synthetic leather, mesh
# - **Waterproof:** Yes
# - **Color:** Black
# - **Sizes:** 7-12 (US)
# - **Toe & Heel Protection:** Reinforced for added durability
# - **Insole Type:** Cushioned and removable for customization
# - **Closure Type:** Quick-lace system
#
# **Why Choose TrailWalker?**
# The CONTOSO TrailWalker Hiking Shoes are crafted to provide excellent stability and protection, making them a reliable choice for both casual hikers and avid adventurers. With outstanding traction and a lightweight design, these shoes ensure you can tackle any trail with ease.
#
# **Customer Reviews:**
# Our customers rave about the TrailWalker Hiking Shoes, praising their exceptional grip, comfort, and durability. Whether you're exploring rugged mountain terrain or enjoying a leisurely forest walk, these shoes are built to perform.
#
# **Warranty & Returns:**
# Enjoy peace of mind with our limited manufacturer's warranty covering defects in materials and workmanship. Plus, our flexible return policy ensures you can shop with confidence.
#
# Gear up for your next outdoor adventure with the CONTOSO TrailWalker Hiking Shoes. Order now and experience the perfect blend of comfort, durability, and performance.
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_86jx7imv_20241127_064623_531613
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_blpblndj_20241127_064623_536579
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gddk70so_20241127_064623_533245
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_e9uxcbas_20241127_064623_533870
# [2024-11-27 06:46:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Chatcompletions_Create Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 60 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-11-27 06:46:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=60, Back off 60.0 seconds for retry.
# [2024-11-27 06:46:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Chatcompletions_Create Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 60 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-11-27 06:46:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=60, Back off 60.0 seconds for retry.
# [2024-11-27 06:46:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Chatcompletions_Create Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 60 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-11-27 06:46:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=60, Back off 60.0 seconds for retry.
# 2024-11-27 06:46:23 +0000   19297 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-11-27 06:46:26 +0000   19297 execution.bulk     INFO     Finished 1 / 3 lines.
# 2024-11-27 06:46:26 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 3.24 seconds. Estimated time for incomplete lines: 6.48 seconds.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Finished 2 / 3 lines.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 1.7 seconds. Estimated time for incomplete lines: 1.7 seconds.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 1.22 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_e9uxcbas_20241127_064623_533870"
# Run status: "Completed"
# Start time: "2024-11-27 06:46:23.528417+00:00"
# Duration: "0:00:04.244887"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_e9uxcbas_20241127_064623_533870"
#
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Finished 1 / 3 lines.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 4.07 seconds. Estimated time for incomplete lines: 8.14 seconds.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 4.07 seconds. Estimated time for incomplete lines: 8.14 seconds.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Finished 2 / 3 lines.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 2.29 seconds. Estimated time for incomplete lines: 2.29 seconds.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Finished 1 / 3 lines.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 4.81 seconds. Estimated time for incomplete lines: 9.62 seconds.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 2.17 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Finished 2 / 3 lines.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 3.33 seconds. Estimated time for incomplete lines: 3.33 seconds.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 2.32 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-11-27 06:46:23 +0000   19297 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Finished 1 / 3 lines.
# 2024-11-27 06:46:27 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 4.07 seconds. Estimated time for incomplete lines: 8.14 seconds.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Finished 2 / 3 lines.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 2.29 seconds. Estimated time for incomplete lines: 2.29 seconds.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 2.17 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_blpblndj_20241127_064623_536579"
# Run status: "Completed"
# Start time: "2024-11-27 06:46:23.535755+00:00"
# Duration: "0:00:07.348790"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_blpblndj_20241127_064623_536579"
#
# 2024-11-27 06:46:23 +0000   19297 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Finished 1 / 3 lines.
# 2024-11-27 06:46:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 4.81 seconds. Estimated time for incomplete lines: 9.62 seconds.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Finished 2 / 3 lines.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 3.33 seconds. Estimated time for incomplete lines: 3.33 seconds.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-11-27 06:46:30 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 2.32 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gddk70so_20241127_064623_533245"
# Run status: "Completed"
# Start time: "2024-11-27 06:46:23.528318+00:00"
# Duration: "0:00:07.377133"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gddk70so_20241127_064623_533245"
#
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Finished 1 / 3 lines.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 64.37 seconds. Estimated time for incomplete lines: 128.74 seconds.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Finished 2 / 3 lines.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 32.27 seconds. Estimated time for incomplete lines: 32.27 seconds.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 21.7 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-11-27 06:46:23 +0000   19297 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Finished 1 / 3 lines.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 64.37 seconds. Estimated time for incomplete lines: 128.74 seconds.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Finished 2 / 3 lines.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 32.27 seconds. Estimated time for incomplete lines: 32.27 seconds.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-11-27 06:47:28 +0000   19297 execution.bulk     INFO     Average execution time for completed lines: 21.7 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_86jx7imv_20241127_064623_531613"
# Run status: "Completed"
# Start time: "2024-11-27 06:46:23.531037+00:00"
# Duration: "0:01:06.357976"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_86jx7imv_20241127_064623_531613"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:04.244887",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_e9uxcbas_20241127_064623_533870"
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:07.377133",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gddk70so_20241127_064623_533245"
#     },
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:00:07.348790",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_blpblndj_20241127_064623_536579"
#     },
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:01:06.357976",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_86jx7imv_20241127_064623_531613"
#     }
# }
#
# ====================================================
#
# Evaluation results saved to "/workspaces/aitour-concept-to-creation-ai-studio/src/web_designer_app/eval_results.jsonl".

# %%
eval_result = pd.DataFrame(result_eval["rows"])
print("-----Summarized Metrics-----")
print(result_eval["metrics"])
print("-----Tabular Result-----")
eval_result.head()
# Out:
# -----Summarized Metrics-----
# {'relevance.relevance': 5.0, 'relevance.gpt_relevance': 5.0, 'fluency.fluency': 4.0, 'fluency.gpt_fluency': 4.0, 'coherence.coherence': 5.0, 'coherence.gpt_coherence': 5.0, 'groundedness.groundedness': 5.0, 'groundedness.gpt_groundedness': 5.0}
# -----Tabular Result-----
#                                         inputs.query  \
# 0  Create the website copy for the tents catalog ...
# 1  Create the textual assets for the sleeping bag...
# 2  Draft the website copy for the hiking shoes we...
#
#                                       inputs.context  \
# 0  ## Task\nYou serve as a web copywriter for the...
# 1  ## Task\nYou serve as a web copywriter for the...
# 2  ## Task\nYou serve as a web copywriter for the...
#
#                                      inputs.response  \
# 0  Welcome to the CONTOSO Outdoor Tents Collectio...
# 1  Welcome to CONTOSO's Sleeping Bags Collection!...
# 2  **CONTOSO TrailWalker Hiking Shoes**\n\nEmbark...
#
#    outputs.relevance.relevance  outputs.relevance.gpt_relevance  \
# 0                            5                                5
# 1                            5                                5
# 2                            5                                5
#
#                   outputs.relevance.relevance_reason  outputs.fluency.fluency  \
# 0  The RESPONSE is directly relevant to the QUERY...                        4
# 1  The RESPONSE effectively addresses the QUERY b...                        4
# 2  The RESPONSE fully addresses the QUERY with co...                        4
#
#    outputs.fluency.gpt_fluency  \
# 0                            4
# 1                            4
# 2                            4
#
#                       outputs.fluency.fluency_reason  \
# 0  The RESPONSE is well-articulated, uses a varie...
# 1  The RESPONSE is well-articulated, with no gram...
# 2  The RESPONSE is well-articulated, uses appropr...
#
#    outputs.coherence.coherence  outputs.coherence.gpt_coherence  \
# 0                            5                                5
# 1                            5                                5
# 2                            5                                5
#
#                   outputs.coherence.coherence_reason  \
# 0  The RESPONSE is well-structured, with each ten...
# 1  The RESPONSE is well-organized, directly addre...
# 2  The RESPONSE is well-structured, with clear se...
#
#    outputs.groundedness.groundedness  outputs.groundedness.gpt_groundedness  \
# 0                                  5                                      5
# 1                                  5                                      5
# 2                                  5                                      5
#
#             outputs.groundedness.groundedness_reason  line_number
# 0  The RESPONSE accurately reflects the CONTEXT b...            0
# 1  The RESPONSE is fully grounded and complete as...            1
# 2  The RESPONSE is fully grounded and complete, a...            2

# %%
# Get the link to visualize eval results to Azure AI Studio
result_eval["studio_url"]
# Out:
# 'https://ai.azure.com/build/evaluation/f28969a3-c3c4-4536-a009-f63aad01e24d?wsid=/subscriptions/6fe5cf97-a734-4ca7-ac31-5bf9d70e9a26/resourceGroups/contoso-website-designer/providers/Microsoft.MachineLearningServices/workspaces/contoso-website-designer'
